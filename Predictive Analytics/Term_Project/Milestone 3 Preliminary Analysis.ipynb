# %% [markdown]
# # Predictive Analytics: Milestone 3
# #### Joshua Greenert, Gabriel Avinaz, and Mithil Patel
# #### DSC630-T301 Predictive Analytics
# #### 12/26/2022

# %%
# Import the required libaries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %%
# Pull in the data.  Each person can have their own path.  Comment out the one that isn't yours if different.
# Josh G
# df_steam_reviews = pd.read_csv('../../../../../Downloads/steam_reviews.csv')
# Gabe A
df_steam_reviews = pd.read_csv('steam_reviews.csv', low_memory=False)

# %%
# Show the head of the dataframe to confirm the data is present.
df_steam_reviews.head(5)
# Out:
#    Unnamed: 0  app_id                  app_name  review_id  language  \
# 0           0  292030  The Witcher 3: Wild Hunt   85185598  schinese
# 1           1  292030  The Witcher 3: Wild Hunt   85185250  schinese
# 2           2  292030  The Witcher 3: Wild Hunt   85185111  schinese
# 3           3  292030  The Witcher 3: Wild Hunt   85184605   english
# 4           4  292030  The Witcher 3: Wild Hunt   85184287  schinese
#
#                                               review  timestamp_created  \
# 0                            不玩此生遗憾，RPG游戏里的天花板，太吸引人了         1611381629
# 1                                 拔DIAO无情打桩机--杰洛特!!!         1611381030
# 2                                              巫师3NB         1611380800
# 3  One of the best RPG's of all time, worthy of a...         1611379970
# 4                                                 大作         1611379427
#
#    timestamp_updated  recommended  votes_helpful  ...  steam_purchase  \
# 0         1611381629         True              0  ...            True
# 1         1611381030         True              0  ...            True
# 2         1611380800         True              0  ...            True
# 3         1611379970         True              0  ...            True
# 4         1611379427         True              0  ...            True
#
#    received_for_free  written_during_early_access     author.steamid  \
# 0              False                        False  76561199095369542
# 1              False                        False  76561198949504115
# 2              False                        False  76561199090098988
# 3              False                        False  76561199054755373
# 4              False                        False  76561199028326951
#
#    author.num_games_owned  author.num_reviews  author.playtime_forever  \
# 0                       6                   2                   1909.0
# 1                      30                  10                   2764.0
# 2                       5                   1                   1061.0
# 3                       5                   3                   5587.0
# 4                       7                   4                    217.0
#
#    author.playtime_last_two_weeks  author.playtime_at_review  \
# 0                          1448.0                     1909.0
# 1                          2743.0                     2674.0
# 2                          1061.0                     1060.0
# 3                          3200.0                     5524.0
# 4                            42.0                      217.0
#
#    author.last_played
# 0        1.611343e+09
# 1        1.611386e+09
# 2        1.611384e+09
# 3        1.611384e+09
# 4        1.610788e+09
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Data Preparation

# %%
# Using the language column, we can remove all other languages besides english.
df_steam_reviews = df_steam_reviews[df_steam_reviews['language'] == 'english']

# %%
# Drop the columns that we don't need.
df_steam_reviews = df_steam_reviews.drop(['Unnamed: 0', 'review_id', 'language','author.num_games_owned', 'author.last_played' ], axis = 1)

# %%
# Make dummies of the columns that can conform.
df_reviews_dummies = pd.get_dummies(df_steam_reviews, columns=['recommended', 'steam_purchase', 'received_for_free',
                                                              'written_during_early_access'])

# %%
df_reviews_dummies.head(5)
# Out:
#     app_id                  app_name  \
# 3   292030  The Witcher 3: Wild Hunt
# 5   292030  The Witcher 3: Wild Hunt
# 6   292030  The Witcher 3: Wild Hunt
# 18  292030  The Witcher 3: Wild Hunt
# 20  292030  The Witcher 3: Wild Hunt
#
#                                                review  timestamp_created  \
# 3   One of the best RPG's of all time, worthy of a...         1611379970
# 5              good story, good graphics. lots to do.         1611379264
# 6                                            dis gud,         1611379091
# 18  favorite game of all time cant wait for the Ne...         1611373086
# 20                          Why wouldn't you get this         1611371978
#
#     timestamp_updated  votes_helpful  votes_funny  weighted_vote_score  \
# 3          1611379970              0            0                  0.0
# 5          1611379264              0            0                  0.0
# 6          1611379091              0            0                  0.0
# 18         1611373086              0            0                  0.0
# 20         1611371978              0            0                  0.0
#
#     comment_count     author.steamid  ...  author.playtime_last_two_weeks  \
# 3               0  76561199054755373  ...                          3200.0
# 5               0  76561198170193529  ...                           823.0
# 6               0  76561198119302812  ...                          3398.0
# 18              0  76561198065591528  ...                           177.0
# 20              0  76561198996835044  ...                          2004.0
#
#     author.playtime_at_review  recommended_False  recommended_True  \
# 3                      5524.0                  0                 1
# 5                       823.0                  0                 1
# 6                      4192.0                  0                 1
# 18                    23329.0                  0                 1
# 20                     8557.0                  0                 1
#
#     steam_purchase_False  steam_purchase_True  received_for_free_False  \
# 3                      0                    1                        1
# 5                      0                    1                        1
# 6                      0                    1                        1
# 18                     0                    1                        1
# 20                     0                    1                        1
#
#     received_for_free_True  written_during_early_access_False  \
# 3                        0                                  1
# 5                        0                                  1
# 6                        0                                  1
# 18                       0                                  1
# 20                       0                                  1
#
#     written_during_early_access_True
# 3                                  0
# 5                                  0
# 6                                  0
# 18                                 0
# 20                                 0
#
# [5 rows x 22 columns]

# %%
lemmatizer = WordNetLemmatizer()
porter = PorterStemmer()
VERB_CODES = {'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'}

def process_sentence_lemmatize(text):
    # changing to lower case, tokenizing, and lemmatizing each fo teh descriptions
    text = str(text).lower()
    temp_sent =[]
    words = word_tokenize(text)
    tags = nltk.pos_tag(words)
    for i, word in enumerate(words):
        if tags[i][1] in VERB_CODES: 
            lemmatized = lemmatizer.lemmatize(word, 'v')
        else:
            lemmatized = lemmatizer.lemmatize(word)
        if lemmatized not in stop_words and lemmatized.isalpha():
            temp_sent.append(lemmatized)
    # joining tokenized words and removing contractions
    finalsent = ' '.join(temp_sent)
    finalsent = finalsent.replace("n't", " not")
    finalsent = finalsent.replace("'m", " am")
    finalsent = finalsent.replace("'s", " is")
    finalsent = finalsent.replace("'re", " are")
    finalsent = finalsent.replace("'ll", " will")
    finalsent = finalsent.replace("'ve", " have")
    finalsent = finalsent.replace("'d", " would")
    return finalsent

def process_sentence_stemm(text):
# changing to lower case, tokenizing, and stemm each fo teh descriptions
    text = str(text).lower()
    temp_sent =[]
    words = word_tokenize(text)
    tags = nltk.pos_tag(words)
    for word in words:
        words = porter.stem(word) 
    words = ' '.join([word for word in words])

    # joining tokenized words and removing contractions
    finalsent = ' '.join(temp_sent)
    finalsent = finalsent.replace("n't", " not")
    finalsent = finalsent.replace("'m", " am")
    finalsent = finalsent.replace("'s", " is")
    finalsent = finalsent.replace("'re", " are")
    finalsent = finalsent.replace("'ll", " will")
    finalsent = finalsent.replace("'ve", " have")
    finalsent = finalsent.replace("'d", " would")
    return finalsent

# %% [markdown]
# ## This takes 6 hours

# %%
df_reviews_dummies['prepped_review_lemm'] = df_reviews_dummies.review.apply(process_sentence_lemmatize)
df_reviews_dummies.sample(10)
# Out:
#            app_id                   app_name  \
# 8218311   1145360                      Hades
# 4055867    646570             Slay the Spire
# 9488630    205100                 Dishonored
# 8914836    698780  Doki Doki Literature Club
# 3723523    367520              Hollow Knight
# 13285339   271590         Grand Theft Auto V
# 2782072    732810                 Slipstream
# 10679606   526870               Satisfactory
# 7089760    945360                   Among Us
# 8543122   1289310                  Helltaker
#
#                                                      review  \
# 8218311   Reviewing now that I have the appropriate amou...
# 4055867   This game is fun to be bad at.\nIf you're good...
# 9488630   This is one of the best games i've ever played...
# 8914836   Bitch why does it take 80 years to get to the ...
# 3723523   A true gem in the world of video games. Beauti...
# 13285339  Chill game, lots of fun, easy to play, slightl...
# 2782072   It takes a bit of practice to stay on the road...
# 10679606                                            factory
# 7089760   - game concept has been done many times before...
# 8543122   Amazing game for people who like to slowly kil...
#
#           timestamp_created  timestamp_updated  votes_helpful  votes_funny  \
# 8218311          1606369651         1606369651              0            0
# 4055867          1574873305         1574873305              0            0
# 9488630          1417106149         1417106149              0            0
# 8914836          1512507971         1512507971              0            0
# 3723523          1523734498         1523734498              0            0
# 13285339         1562243522         1562243522              0            0
# 2782072          1527316208         1527316208              2            0
# 10679606         1596319623         1596319623              0            0
# 7089760          1600492010         1600492010              0            0
# 8543122          1595458098         1595458182              0            0
#
#           weighted_vote_score  comment_count     author.steamid  ...  \
# 8218311              0.000000              0  76561198048104819  ...
# 4055867              0.000000              0  76561198047293459  ...
# 9488630              0.000000              0  76561198108145398  ...
# 8914836              0.000000              0  76561198163486395  ...
# 3723523              0.000000              0  76561198105228881  ...
# 13285339             0.000000              0  76561198127722097  ...
# 2782072              0.505495              0  76561198139158591  ...
# 10679606             0.000000              0  76561198035374176  ...
# 7089760              0.476190              0  76561198180392223  ...
# 8543122              0.000000              0  76561198140839080  ...
#
#           author.playtime_at_review  recommended_False  recommended_True  \
# 8218311                      4155.0                  0                 1
# 4055867                       345.0                  0                 1
# 9488630                      4844.0                  0                 1
# 8914836                       173.0                  0                 1
# 3723523                      3558.0                  0                 1
# 13285339                     1562.0                  0                 1
# 2782072                       401.0                  0                 1
# 10679606                     3712.0                  0                 1
# 7089760                       292.0                  1                 0
# 8543122                       117.0                  0                 1
#
#           steam_purchase_False  steam_purchase_True  received_for_free_False  \
# 8218311                      0                    1                        1
# 4055867                      0                    1                        1
# 9488630                      0                    1                        1
# 8914836                      1                    0                        1
# 3723523                      0                    1                        1
# 13285339                     0                    1                        1
# 2782072                      0                    1                        1
# 10679606                     0                    1                        1
# 7089760                      0                    1                        1
# 8543122                      1                    0                        1
#
#           received_for_free_True  written_during_early_access_False  \
# 8218311                        0                                  1
# 4055867                        0                                  1
# 9488630                        0                                  1
# 8914836                        0                                  1
# 3723523                        0                                  1
# 13285339                       0                                  1
# 2782072                        0                                  1
# 10679606                       0                                  0
# 7089760                        0                                  1
# 8543122                        0                                  1
#
#           written_during_early_access_True  \
# 8218311                                  0
# 4055867                                  0
# 9488630                                  0
# 8914836                                  0
# 3723523                                  0
# 13285339                                 0
# 2782072                                  0
# 10679606                                 1
# 7089760                                  0
# 8543122                                  0
#
#                                         prepped_review_lemm
# 8218311   review appropriate amount hour play game right...
# 4055867                   game fun bad good bet even better
# 9488630   one best game ever play maybe even best really...
# 8914836   bitch take year get scary part smh man game aw...
# 3723523   true gem world video game beautiful challenge ...
# 13285339  chill game lot fun easy play slightly graphic ...
# 2782072   take bit practice stay road get hang driving f...
# 10679606                                            factory
# 7089760   game concept many time ttt town salem cluedo e...
# 8543122   amazing game people like slowly kill sanity re...
#
# [10 rows x 23 columns]

# %%
type(df_reviews_dummies.review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 type(df_reviews_dummies.review)
#
# NameError: name 'df_reviews_dummies' is not defined

# %%
df_reviews_dummies = pd.read_csv('Prepped_test_out.csv', low_memory=False)

# %% [markdown]
# # DONT RUN

# %%
import sys
print(sys.getrecursionlimit())

sys.setrecursionlimit(5000)
# Out:
# 5000

# %%
df_reviews_dummies['prepped_review_stemm'] = df_reviews_dummies.review.apply(process_sentence_stemm)
df_reviews_dummies.sample(10)

# %% [markdown]
# ----------------------------------------------------------------------

# %%
df_reviews_dummies.to_csv('Prepped_test_out.csv', index=False)

# %%
tfidfvec = TfidfVectorizer()

tfidf_reviews = tfidfvec.fit_transform((df_reviews_dummies['prepped_review_lemm'].values.astype('U')))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [6], line 3
#       1 tfidfvec = TfidfVectorizer()
# ----> 3 tfidf_reviews = tfidfvec.fit_transform((df_reviews_dummies['prepped_review_lemm'].values.astype('U')))
#
# MemoryError: Unable to allocate 306. GiB for an array with shape (9635437,) and data type <U8519
