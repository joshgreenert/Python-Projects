# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix

# %%
df_steam_games = pd.read_csv('Prepped_games_out.csv')
# df_steam_games = df_steam_games.set_index('App ID')

# %%
df_steam_games.sample(20)
# Out:
#         App ID                                          Name  \
# 20600  1704980        Jigsaw Puzzle - Jack and the Beanstalk
# 26261  2012630  A Pact With Me - Boys Love (BL) Visual Novel
# 17071  1549420                            メンヘラフレシア　フラワリングアビス
# 37517   502320               Boulder Dash - 30th Anniversary
# 24177  1885880                           Might of the Stones
# 51242   872040                               Hovership Havoc
# 38401   525460                  Sullen: Light is Your Friend
# 34844   424010                                      Crudelis
# 27596  2126700                                Double Trouble
# 5674   1162430                                  Salad Fields
# 47267   766740                            Maze Of Adventures
# 47682   777550                                   King Battle
# 53379   932250                                         rOt 2
# 14067  1442070                        Claire's Cruisin' Cafe
# 36753   478980                           Mansions of Madness
# 10229  1307880                    Hanoi Puzzles: Solid Match
# 42366   639220                             Throttle Powah VR
# 9645   1287450                                Ultimate Chess
# 1951   1055240                                      Hollow 2
# 15819  1503630                     Arm of Revenge Re-Edition
#
#                                        Short Description  Positive Reviews  \
# 20600  Once upon a time... If you like Jigsaw Puzzles...                10
# 26261  Three humans summon Belial, a mischievous demo...                10
# 17071  フリーゲーム原作「メンヘラフレシア」リメイク作品 メンヘラな少女たちを攻略する恋愛アドベンチ...                25
# 37517  Boulder Dash® - 30th Anniversary™ features cla...                79
# 24177  The world is in danger. An evil entity is tryi...                 3
# 51242  Hovership Havoc is a sci-fi twin stick shooter...                21
# 38401  FIVE YEARS AGO IN THIS FOREST.. A journalist w...                12
# 34844  Crudelis is a 60 minutes RPG game, during whic...                20
# 27596  Meet Olivia and Elodie, two sisters on an adve...                 4
# 5674   A DREAMYQUEER experience. It's an adventure-pu...                24
# 47267  An unсommon puzzle game with a story! Your goa...                20
# 47682  R &amp; D team effort for several years, focus...                 2
# 53379  Minimal puzzle game which goal is to get The B...                17
# 14067  Set off on a cross-country journey to feed the...                25
# 36753  A companion app for the Mansions of Madness Se...               816
# 10229  A new game concept inspired by the classic Tow...                44
# 42366  Welcome to a fresh multiplayer, VR, racing, fr...                37
# 9645             Play chess against yourself or a friend                 4
# 1951   Once again, you are on board Shakhter-One. Tra...                 7
# 15819  &quot;Arm of Revenge&quot; A arcade style plat...                20
#
#        Negative Reviews  Total Reviews  \
# 20600                 0             10
# 26261                 0             10
# 17071                 1             26
# 37517                19             98
# 24177                 0              3
# 51242                 5             26
# 38401                34             46
# 34844                 4             24
# 27596                 0              4
# 5674                  0             24
# 47267                 1             21
# 47682                 3              5
# 53379                18             35
# 14067                 4             29
# 36753                68            884
# 10229                 0             44
# 42366                10             47
# 9645                  2              6
# 1951                  5             12
# 15819                 5             25
#
#                                 prepped_description_lemm
# 20600  upon time like jigsaw puzzle nice story game f...
# 26261  three human summon belial mischievous demon fo...
# 17071                         メンヘラな少女たちを攻略する恋愛アドベンチャーゲーム
# 37517  boulder feature classic gameplay exciting leve...
# 24177  world danger evil entity try destroy world job...
# 51242  hovership havoc twin stick shooter person bos ...
# 38401  five year ago forest journalist want go course...
# 34844  crudelis minute rpg game every decision meanin...
# 27596  meet olivia elodie two sister adventure infini...
# 5674   dreamyqueer experience game surreal place weir...
# 47267  unсommon puzzle game story goal help brave adv...
# 47682  r amp team effort several year focus show beau...
# 53379  minimal puzzle game goal get ball winbox use c...
# 14067  set journey fee famished mass gourmet food tru...
# 36753  companion app mansion madness second edition b...
# 10229  new game concept inspire classic tower hanoi a...
# 42366  welcome fresh multiplayer vr racing freestyle ...
# 9645                                   play chess friend
# 1951   board traverse deck mining ship depth mark twi...
# 15819  quot arm revenge quot arcade style platform ac...

# %%
game_names = dict(zip(df_steam_games['App ID'], df_steam_games['Name']))

df_game_desc = df_steam_games[["App ID", "prepped_description_lemm"]]
df_game_desc.columns = ['ID', 'Description']
game_desc_df = df_game_desc.set_index('ID')
game_desc_df = game_desc_df.dropna()
game_desc_df.sample(10)
# Out:
#                                                Description
# ID
# 1076290  immerse dark virtual thriller police detective...
# 1082000  help nathan beat platformer part tournament gr...
# 1422150  pp puncher rpg mostly guy go quest save waifus...
# 1267170  explore underground solve puzzle get skill fig...
# 525920   become manager professional cycling team compe...
# 723420   vr game traditional chinese mythology game act...
# 292230   game character hub art program focus game asse...
# 820310   adventure saga create best tradition fantasy t...
# 390720   anarcute rampage riot simulator combine adorab...
# 1147140  biggest police chase town run get catch steal ...

# %%
# Create the td-idf vectorizer. 
tfidfvec = TfidfVectorizer()

# Fit the model 
tfidf_gamedesc = tfidfvec.fit_transform((game_desc_df['Description']))

# Add cosine similarity
cos_sim = cosine_similarity(tfidf_gamedesc, tfidf_gamedesc)

# functions for retrieving similar game IDs from cos_sim
indices = pd.Series(game_desc_df.index)

# %%
'''
Create a new function to get the data by the game's descriptions.
Returns a list of recommended games from the model.

@param: id: id of the game to get recommendations on.
@param: total_matches: total number of matches to return.
'''
def get_related_games_by_desc(id, total_matches):
    
    # Set a new dataframe to return.
    recommended_games =  pd.DataFrame()
    
    # Set the index variable.
    index = indices[indices == id].index[0]
    
    # Increment total_matches to be 1 higher.
    total_matches += 1
    
    # Obtain the list of cosine similiarities and set them into a series.
    similarity_scores = pd.Series(cos_sim[index]).sort_values(ascending = False)
    top = list(similarity_scores.iloc[1:total_matches].index)
    recommended_games['Score'] = similarity_scores.iloc[1:total_matches]
    
    # Create a new list.
    app_ids = []
    
    # Loop over and set the top items in the list.
    for i in top:
        app_ids.append(list(df_steam_games.index)[i])
    recommended_games['App ID'] = app_ids
    
    print(f"Games related to: {df_steam_games.loc[df_steam_games.index == game_id].Name.values[0]}\n")
    for i, val in enumerate(recommended_games["App ID"]):
        print(f"{df_steam_games.loc[df_steam_games.index == val].Name.values[0]}: {recommended_games.Score.values[i]:.2f}")

# %%
def get_recommendations(id):
    recommended_games = []
    index = indices[indices == id].index[0]
    similarity_scores = pd.Series(cos_sim[index]).sort_values(ascending = False)
    top = list(similarity_scores.iloc[1:11].index)
    for i in top:
        recommended_games.append(list(game_desc_df.index)[i])
    return recommended_games

# %%
game_id = 221380
  
recommended_games = get_recommendations(game_id)
  
print(f"Games related to: {game_names[game_id]}")
for i in recommended_games:
    print(game_names[i])
# Out:
# Games related to: Age of Empires II (2013)
# Age of Mythology: Extended Edition
# Rise of Nations: Extended Edition
# Spades
# Spectre
# Escape Legacy: Ancient Scrolls
# DRAKERZ-Confrontation
# Project Beril / 贝丽尔养成计划
# Age of Empires II: Definitive Edition
# Age of Wonders II: The Wizard's Throne
# Akin

# %%
game_id = 1287450
  
recommended_games = get_recommendations(game_id)
  
print(f"Games related to: {game_names[game_id]}")
for i in recommended_games:
    print(game_names[i])
# Out:
# Games related to: Ultimate Chess
# The Rooster's Chess
# Chessmates
# The Chess Variants Club
# ChessCraft
# Chesskoban - Chess Puzzles
# Ragnarok Chess
# Chessia
# Wild Wild Chess
# Samurai Chess
# ChessLocke
