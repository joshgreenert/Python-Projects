# %% [markdown]
# # Assignment 11 & 12: Charts
# #### Joshua Greenert
# #### DSC640-T301 Data Presentation and Visualization
# #### 2/19/2023

# %%
# Import the required libaries for plotting.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the dataset.
df_education = pd.read_csv('education.csv')
df_education.head(5)
# Out:
#            state  reading  math  writing  percent_graduates_sat  \
# 0  United States      501   515      493                     46
# 1        Alabama      557   552      549                      7
# 2         Alaska      520   516      492                     46
# 3        Arizona      516   521      497                     26
# 4       Arkansas      572   572      556                      5
#
#    pupil_staff_ratio  dropout_rate
# 0                7.9           4.4
# 1                6.7           2.3
# 2                7.9           7.3
# 3               10.4           7.6
# 4                6.8           4.6

# %%
# Pull in the other datasets.
df_crime = pd.read_csv('crimeratesbystate-formatted.csv')
df_birth = pd.read_csv('birth-rate.csv')

# %%
# Histogram
fig, axes = plt.subplots(1, 1, figsize=(14, 8))
axes.set_title('Python Histogram')

# Create the histogram with kernel density estimate.
sns.histplot(data = df_education, x="math", binwidth=10, kde=True)
# Out:
# <AxesSubplot:title={'center':'Python Histogram'}, xlabel='math', ylabel='Count'>

# %%
# Boxplot
fig, axes = plt.subplots(1, 1, figsize=(14, 8))
axes.set_title('Python Boxplot')

# Create a sns boxplot with writing by pupiil-staff ratio
sns.boxplot(data = df_education, x="writing", y="pupil_staff_ratio")
# Out:
# <AxesSubplot:title={'center':'Python Boxplot'}, xlabel='writing', ylabel='pupil_staff_ratio'>

# %%
# Bullet Chart
import plotly.figure_factory as ff

# Create a data object to hold the values to display.
data = [
    {"title": "Reading",
     "ranges": [df_education["reading"].min(), df_education["reading"].mean(), df_education["reading"].max()],
     "measures":[466, 533],
     "markers": [int(df_education["reading"].mean())]},
  
    {"title": "Math",
     "ranges": [df_education["math"].min(), df_education["math"].mean(), df_education["math"].max()],
     "measures":[451, 538],
     "markers": [int(df_education["math"].mean())]},
      
    {"title": "Writing",
     "ranges": [df_education["writing"].min(), df_education["writing"].mean(), df_education["writing"].max()],
     "measures":[455,520],
     "markers": [int(df_education["writing"].mean())]}
]

# Use plotly to create the bullet chart.
fig = ff.create_bullet(
    data, titles='title',
    markers='markers',
    measures='measures',
    ranges='ranges', 
    orientation='h',
    title='Python Bullet Chart'
)
  
fig.show()
# Out:
# <div>                            <div id="b4558fcb-8484-4684-9477-269e81b14792" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4558fcb-8484-4684-9477-269e81b14792")) {                    Plotly.newPlot(                        "b4558fcb-8484-4684-9477-269e81b14792",                        [{"base":0,"hoverinfo":"x","marker":{"color":"rgb(245.0, 245.0, 245.0)"},"name":"ranges","orientation":"h","width":2,"x":[610],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"base":0,"hoverinfo":"x","marker":{"color":"rgb(222.5, 222.5, 222.5)"},"name":"ranges","orientation":"h","width":2,"x":[533.8076923076923],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"base":0,"hoverinfo":"x","marker":{"color":"rgb(200.0, 200.0, 200.0)"},"name":"ranges","orientation":"h","
# ...

# %%
# One additional Chart
df_education["reading"].min()
# Out:
# 466
